# %% [markdown]
# <a href="https://colab.research.google.com/github/giselalsouto/LC-bluesky-sentiment/blob/b2/Copy_of_analizar_sentimentos_bsky_b2_v0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Seleção de toots e análise de sentimentos em Google Colab
#
# A) Seleção de posts:
#
#     Configura bluesky-scrape para selecionar posts sobre uma entidade (indivíduo, empresa, produto, localidade, etc) que consideres relevante.
#
#     Guarda os resultados num ficheiro e aplica o módulo de sentimentos de Linguakit.
#
#     Analisa uma amostra dos posts, identifica os erros do sistema (mal classificados) e procura uma explicação para alguns dos casos errados.
#
# B) Melhora o dicionário polarizado:
#
#     Abre um dos dicionários do módulo de análise de sentimentos de Linguakit (gl, pt, en, es) e procura palavras polarizadas que não estão mas deveriam estar.
#
#     Adiciona essas palavras ao dicionário.
#
#     Analisa frases que contenham essas palavras.
#
# C) Elabora o teu próprio dicionario polarizado numa das 4 línguas de Linguakit
#
#     Cria um novo ficheiro com a lista de palavras polarizadas que consideres essenciais.
#
#     Sube-o a Google Colab e coloca-o no lugar ajeitado com o mesmo nome que o dicionário antigo.
#
#     Prepara uma lista de frases de teste e prova o analisador com o teu novo dicionário.
#
# D) Entrega dos documentos para serem avaliados:
#
#     Documento de uma ou duas folhas em PDF que contenha a ligação ao teu Google Colab e uma breve explicação do que foi feito nos pontos A, B e C: erros analisados, que novas palavras fórom adicionadas ao dicionário existente, frases utilizadas para testar o sistema com o dicionário modificado (ponto B) e com o novo dicionário (ponto C), etc.

# %% [markdown]
# A) Seleção de posts:
#
#     Configura bluesky-scrape para selecionar posts sobre uma entidade (indivíduo, empresa, produto, localidade, etc) que consideres relevante.
#
#     Guarda os resultados num ficheiro e aplica o módulo de sentimentos de Linguakit.
#
#     Analisa uma amostra dos posts, identifica os erros do sistema (mal classificados) e procura uma explicação para alguns dos casos errados.

# %% [markdown]
# # A.1.  Descarga e instalación de bluesky-scrape.

# %% [markdown]
# ## A.1.1. Comprobación de dependencias

# %% [markdown]
# Antes de descargar e instalar o software que imos empregar para facer a descarga do contido, imos ver se temos os paquetes requiridos para iso.

# %% [markdown]
# Neste caso, serían os paquetes `json` (para poder empregar arquivos en formato json) e `requests`que é un paquete para fecer solicitudes HTTP para recuperar información desde a Web.

# %%
import json, requests
# Tamén imos importar a biblioteca os para poder navegar entre ficheiros e usar \
# os propios ficheiros.
import os

# %% [markdown]
# Ao non dar erros, esto indica que os paquetes xa se atopan no sistema.

# %% [markdown]
# ## A.1.2. Instalación de biblioteca *bluesky-scrape*
#
# Unha vez comprobadas as dependencias, e ao non ter que instalar ningunha, imos instalar, *bluesky-scrape*.

# %% [markdown]
# Para esta instalación, primeiro temos que descargar o repositorio, por medio de git.

# %%
existe = os.path.exists('/content/bluesky-scrape/')
if ( not existe) :
  # !git clone https://github.com/gamallo/bluesky-scrape.git

# %% [markdown]
# Agora, miramos onde descargou o git o contido mediante `ls`-

# %%
# !ls -lF
# Out:
# total 12
# drwxr-xr-x 4 root root 4096 May 18 10:32 bluesky-scrape/
# drwx------ 6 root root 4096 May 18 10:28 drive/
# drwxr-xr-x 1 root root 4096 May 14 13:38 sample_data/

# %% [markdown]
# Como vemos, o contido está nunha carpeta chamada *bluesky-scrape*.
#
# Os parámetros empregados no `ls` son `-l` (visualización en formato longo con variada información) e)`-F`(marcar con `/` ao final os directorios).

# %% [markdown]
# Agora imos a ver de por o contrasinal sen que se vexa

# %%
##ISTO É SÓ PARA OCULTAR O MEU PASSWORD
from google.colab import userdata
bs_passw = userdata.get('bsky_pass')

# %%
import os
os.chdir('/content/bluesky-scrape/')
if (not os.path.exists('/content/bluesky-scrape/results/')):
  os.mkdir('/content/bluesky-scrape/results/')
os.listdir()
# Out:
# ['results',
#  'old_bluesky-scraper.py',
#  'bluesky-scraper.py',
#  '.git',
#  'LICENSE',
#  'README.md']

# %%
import shutil

# %%
import requests
import json
import sys
from datetime import datetime, timedelta

username = "giselals.bsky.social" ## Coloca aqui o teu usuário
password = bs_passw  # Coloca aqui o teu password
keyword = "israel"

limit = 25 ##número máximo de posts
since = "2025-04-01" #data de início
until = "2025-05-16" #data de fim
lang = "es" #língua do post: en, es, gl, pt, fr, ...

BASE_URL = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"

# %%
def authenticate(username, password):
    """
    Autenticar na Bluesky e obter um token de acesso.
    """
    auth_url = "https://bsky.social/xrpc/com.atproto.server.createSession"
    data = {
        "identifier": username,
        "password": password
    }
    response = requests.post(auth_url, json=data)
    response.raise_for_status()
    return response.json().get("accessJwt")

# %%
def search_posts(keyword, access_token, start_date=since, end_date=until, limit=limit, lang=None):
    """
    Pesquisa por mensagens que contenham a palavra-chave especificada.
    """
    headers = {
        "Authorization": f"Bearer {access_token}"
    }
    params = {
        "q": keyword,
        "limit": limit
    }
    if start_date:
        params["since"] = f"{start_date}T00:00:00Z"
    if end_date:
        params["until"] = f"{end_date}T23:59:59Z"
    if lang:
        params["lang"] = lang

    response = requests.get(BASE_URL, headers=headers, params=params)
    response.raise_for_status()
    return response.json().get("posts", [])

# %%
def save_to_file(keyword, posts):
    """
    Guardar os posts num ficheiro json.
    """
    filename = f"{keyword.replace(' ', '_')}_results.json"
    with open(filename, "w", encoding="utf-8") as file:
        json.dump(posts, file, indent=4, ensure_ascii=False)
    print(f"Guardar resultados de '{keyword}' em {filename}")

# %%
def save_text_only(keyword, posts):
    """
    Guardar só o texto dos posts num ficheiro .txt
    """
    filename = f"{keyword.replace(' ', '_')}_results.txt"
    with open(filename, "w", encoding="utf-8") as file:
        for post in posts:
            text = post.get("record", {}).get("text", "")
            if text:
                file.write(text.replace("\n", " ").strip() + "\n")
    print(f"Guardar só texto sobre '{keyword}' em {filename}")

# %%
def scrape():

    # Autenticar-se
    try:
        access_token = authenticate(username, password)
    except requests.exceptions.RequestException as e:
        print(f"Authentication error: {e}")
        sys.exit(1)

    # Procurar posts
    try:
        posts = search_posts(keyword, access_token, start_date=since, end_date=until, limit=limit, lang=lang)
    except requests.exceptions.RequestException as e:
        print(f"Search error: {e}")
        sys.exit(1)

    for post in posts:
        text = post.get("record", {}).get("text", "No content")
        author = post.get("author", {}).get("displayName", "Unknown Author")
        created_at = post.get("record", {}).get("createdAt", "Unknown Date")
        print(f"Author: {author}\nCreated At: {created_at}\nContent: {text}\n{'-' * 40}")

    # Guardar posts
    save_to_file(keyword, posts)
    save_text_only(keyword, posts)

# %%
import re
def replace_punctuation ( text, replace ):
  return re.sub('[%s]' % re.escape(string.punctuation), replace, text)

# %%
scrape()
# Out:
# Author: Luicántropo
# Created At: 2025-05-16T23:58:05.634Z
# Content: Tengo ya depresión post-eurovisión, y eso que aún no ha acabado. Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa.
#
# Tampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel.
# ----------------------------------------
# Author: Rubén Darío
# Created At: 2025-05-16T23:56:32.014Z
# Content: Israel OG
# 🖼️
# Soy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras.
#  ⁣
#    ☯️     Fiódor Dostoievski
# ----------------------------------------
# Author: Manuel Ibáñez
# Created At: 2025-05-16T23:56:31.441Z
# Content: INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo.
# BIEN!!! 👍👍💪🏼🇵🇸
# ----------------------------------------
# Author: Carlos Rolling
# Created At: 2025-05-16T23:52:46.559Z
# Content: Si después de esto no betan a Israel ojalá y nos retiremos. Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas.
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:45:30.999Z
# Content: EEUU.
# Lo detuvieron porque está contra Israel.
# El genocidio en gaza.
# ----------------------------------------
# Author: .ñ.
# Created At: 2025-05-16T23:42:40.015Z
# Content: España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio.
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:33:50.073Z
# Content: There probably will be. Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist.
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:31:45.829Z
# Content: Porque aceptan a Israel? Si no tiene nada que ver con Europa. O acaso permiten participar a países no europeos? Pregunto por mi ignorancia
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:31:29.584Z
# Content: Como siempre Wyoming lo dice más claro imposible. Israel es un país genocida y el que lo apoye es cómplice.
# ----------------------------------------
# Author: Awakari
# Created At: 2025-05-16T23:26:13Z
# Content: Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia  Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye...
#
# | Details | Interest | Feed |
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:26:00.142Z
# Content: Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas
#
# Fuente: EL PAÍS
#  search.app/xfN3C
#
# Compartido mediante la aplicación Google
# ----------------------------------------
# Author: Natalia Brezina  ⛱  ȺᏒ
# Created At: 2025-05-16T23:21:59.345Z
# Content: Se ve que son parientes. Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina. Y el chabón es polaco. Que basura sionista por favor. Mierda sionista. Como el comehermana.
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:19:58.342Z
# Content: Israel.
# Los judíos nazis asesinos.
# Comenzaron el último ataque contra Gaza.
# 😡😡😡😡😡😡😡😡
# ----------------------------------------
# Author: Miguel Máiquez
# Created At: 2025-05-16T23:16:47.000Z
# Content: Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre
#
# https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html
#
# #Israel #Gaza
# ----------------------------------------
# Author: Recortes de Oriente Medio
# Created At: 2025-05-16T23:16:15.000Z
# Content: Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre
#
# https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html
#
# #Israel #Gaza
# ----------------------------------------
# Author: Manuel Ibáñez
# Created At: 2025-05-16T23:15:37.028Z
# Content: BOICOT A ISRAEL!
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:15:36.962Z
# Content: Israel mancha otra final de Eurovisión, bajo la permisividad de la UER a su TV pública y con nueva amenaza de victoria www.eldiario.es/vertele/1_bb...
# ----------------------------------------
# Author:
# Created At: 2025-05-16T23:12:38.611Z
# Content: Fermin Muguruza, Reincidentes y decenas de artistas rechazan actuar en festivales propiedad del fondo con intereses en Israel KKR
#
# Fuente: elDiario.es
#  search.app/pocDb
#
# Compartido mediante la aplicación Google
# ----------------------------------------
# Author: Javi 🌻
# Created At: 2025-05-16T23:12:32.710Z
# Content: Me repito mucho, pero me da igual:
#
# No admito críticas por ver Eurovisión que vengan de peña que ha defendido hasta el último minuto la permanencia de su partido en Sumar y en el Gobierno pese al comercio de armas con Israel.
# ----------------------------------------
# Author: PPenVIVO
# Created At: 2025-05-16T22:51:59.047Z
# Content: 💥 “ES UNA SITUACIÓN SIN PRECEDENTES” TRUMP DA DURO MENSAJE SOBRE ISRAEL ... youtu.be/DRjnZCBaHd0?... a través de @YouTube
# ----------------------------------------
# Author: Ateneu LLibertari de Gràcia
# Created At: 2025-05-16T22:50:24.487Z
# Content: 70 artistas, bandas y DJ internacionales exigen al Sónar que se distancie de las inversiones de KKR en Israel. agraciablog.wordpress.com/2025/05/16/7...
# ----------------------------------------
# Author: Ateneu LLibertari de Gràcia
# Created At: 2025-05-16T22:48:47.450Z
# Content: Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel. agraciablog.wordpress.com/2025/05/16/l...
# ----------------------------------------
# Author: Nacho Montes de Oca
# Created At: 2025-05-16T22:47:50.562Z
# Content: Tal como había prometido Netanyahu, iba a esperar los resultados de la gira del presidente de EEUU por los países árabes antes de tomar una decisión respecto a la ofensiva
# Israel define su propia agenda y comienza el intento definitivo para definir el futuro inmediato de Gaza
# ----------------------------------------
# Author:
# Created At: 2025-05-16T22:46:00.300Z
# Content: Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: "Había más posibilidades que no participara por una canción que por un genocidio"
# www.publico.es/tremending/b...
# ----------------------------------------
# Author: Ivan✌🏼
# Created At: 2025-05-16T22:44:39.011Z
# Content: Es que me lo veía venir, a ver si mañana actuamos, y en el caso de que sea así tened clarisimo que quedamos últimos.
#
# Para la próxima edición sinceramente que salgan de Eurovision los países del big 5, y todos los que estén en contra de que este ahí Israel.
#
# Y que le den a la UER
# ----------------------------------------
# Guardar resultados de 'israel' em israel_results.json
# Guardar só texto sobre 'israel' em israel_results.txt

# %%
import shutil
#xeramos os nomes de arquivo
txt = '.txt'
json = '.json'
results = '_results'
dirres = './results/'
res_txt = keyword + results + txt
res_json = keyword + results + json
path_res_txt = dirres + res_txt
path_res_json = dirres + res_json
##Se non existe o ficheiro de resultados no directorio results
#if (not os.path.exists (path_res_txt)):
#Entón movemos o arquivo de resultados ao directorio results
shutil.move(res_txt , path_res_txt)
##Se non existe o ficheiro de resultados no directorio results
#if (not os.path.exists (path_res_json)):
#Entón movemos o arquivo de resultados ao directorio results
shutil.move(res_json , path_res_json)
# !ls ./results
# !ls
# Out:
# israel_results.json  israel_results.txt
# bluesky-scraper.py  LICENSE  old_bluesky-scraper.py  README.md	results

# %% [markdown]
# ## A.2. Analizar unha mostra dos posts

# %% [markdown]
# Xa co límite de postas (25) só temos unha mostra dos miniartigos de bluesky.
#
# Aquí :
#
# Primeiro creamos as varaibles precisas (`texto_txt`e `texto_json`)
#
# Logo,buscamos os elementos da ruta de cada ficheiro:
#
# - Primeiro, pomos o directorio do ficheiro
# - Logo, montamos o nome do ficheiro por medio dos seus elementos:
#   - o elemento keyword (que é o termo que buscamos en bluesky)
#   - o elemento results ( que engade `_results` ao nome)
#   - a extensión ( que engade `.txt` ou `.json`, segundo o tipo de texto )
#
# Todo isto facémolo para pasar o contido dos arquivos tanto de texto, como JSON  a cadansúa variable.

# %%
texto_txt = ''
texto_json = ''
dir_file_txt  = ('/content/bluesky-scrape/results/')
dir_file_json = ('/content/bluesky-scrape/results/')
results = '_results'
print('results: ', results)
file_txt_path = dir_file_txt + keyword + results + txt
print('Ruta do ficheiro de texto: ',file_txt_path)
file_json_path = dir_file_txt + keyword + results + json
print('Ruta do ficheiro JSON: ', file_json_path)
if (os.path.exists(file_txt_path)):
  print('file_txt_path existe? ', os.path.exists(file_txt_path))
  with (open(file_txt_path,'r')) as file_txt:
    texto_txt = file_txt.read()

if (os.path.exists(file_json_path)):
  print('file_json_path existe? ', os.path.exists(file_json_path))
  with (open(file_json_path,'r')) as file_json:
    texto_json = file_json.read()

print ('Texto ( ', limit, ' posts de Bluesky) : ', texto_txt)
print ('JSON ( ', limit, ' posts de Bluesky) : ',texto_json)
# Out:
# results:  _results
# Ruta do ficheiro de texto:  /content/bluesky-scrape/results/israel_results.txt
# Ruta do ficheiro JSON:  /content/bluesky-scrape/results/israel_results.json
# file_txt_path existe?  True
# file_json_path existe?  True
# Texto (  25  posts de Bluesky) :  Tengo ya depresión post-eurovisión, y eso que aún no ha acabado. Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa.  Tampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel.
# Israel OG 🖼️ Soy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras.  ⁣    ☯️     Fiódor Dostoievski
# INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo. BIEN!!! 👍👍💪🏼🇵🇸
# Si después de esto no betan a Israel ojalá y nos retiremos. Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas.
# EEUU. Lo detuvieron porque está contra Israel. El genocidio en gaza.
# España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio.
# There probably will be. Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist.
# Porque aceptan a Israel? Si no tiene nada que ver con Europa. O acaso permiten participar a países no europeos? Pregunto por mi ignorancia
# Como siempre Wyoming lo dice más claro imposible. Israel es un país genocida y el que lo apoye es cómplice.
# Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia  Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye...  | Details | Interest | Feed |
# Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas  Fuente: EL PAÍS  search.app/xfN3C  Compartido mediante la aplicación Google
# Se ve que son parientes. Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina. Y el chabón es polaco. Que basura sionista por favor. Mierda sionista. Como el comehermana.
# Israel. Los judíos nazis asesinos. Comenzaron el último ataque contra Gaza. 😡😡😡😡😡😡😡😡
# Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza
# Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza
# BOICOT A ISRAEL!
# Israel mancha otra final de Eurovisión, bajo la permisividad de la UER a su TV pública y con nueva amenaza de victoria www.eldiario.es/vertele/1_bb...
# Fermin Muguruza, Reincidentes y decenas de artistas rechazan actuar en festivales propiedad del fondo con intereses en Israel KKR  Fuente: elDiario.es  search.app/pocDb  Compartido mediante la aplicación Google
# Me repito mucho, pero me da igual:  No admito críticas por ver Eurovisión que vengan de peña que ha defendido hasta el último minuto la permanencia de su partido en Sumar y en el Gobierno pese al comercio de armas con Israel.
# 💥 “ES UNA SITUACIÓN SIN PRECEDENTES” TRUMP DA DURO MENSAJE SOBRE ISRAEL ... youtu.be/DRjnZCBaHd0?... a través de @YouTube
# 70 artistas, bandas y DJ internacionales exigen al Sónar que se distancie de las inversiones de KKR en Israel. agraciablog.wordpress.com/2025/05/16/7...
# Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel. agraciablog.wordpress.com/2025/05/16/l...
# Tal como había prometido Netanyahu, iba a esperar los resultados de la gira del presidente de EEUU por los países árabes antes de tomar una decisión respecto a la ofensiva Israel define su propia agenda y comienza el intento definitivo para definir el futuro inmediato de Gaza
# Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: "Había más posibilidades que no participara por una canción que por un genocidio"  www.publico.es/tremending/b...
# Es que me lo veía venir, a ver si mañana actuamos, y en el caso de que sea así tened clarisimo que quedamos últimos.  Para la próxima edición sinceramente que salgan de Eurovision los países del big 5, y todos los que estén en contra de que este ahí Israel.  Y que le den a la UER
#
# JSON (  25  posts de Bluesky) :  [
#     {
#         "uri": "at://did:plc:pyfdbi7fwxmcktuujjodcjfv/app.bsky.feed.post/3lpdaaugljc2j",
#         "cid": "bafyreidwdfrpqj7swy35niwj7urmvvhgnnza7gnissqrh3nzelfbwpr7vu",
#         "author": {
#             "did": "did:plc:pyfdbi7fwxmcktuujjodcjfv",
#             "handle": "luicantropo.bsky.social",
#             "displayName": "Luicántropo",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:pyfdbi7fwxmcktuujjodcjfv/bafkreihusidqv6hx7hjapoyssl5cimng2cnco3tc3uoopoqa2pwoindl4e@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-11-14T13:44:18.025Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:58:05.634Z",
#             "langs": [
#                 "es"
#             ],
#             "text": "Tengo ya depresión post-eurovisión, y eso que aún no ha acabado. Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa.\n\nTampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel."
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:58:07.648Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:zfjxw2pf7uxjtbapshhepiw7/app.bsky.feed.post/3lpda635mo22b",
#         "cid": "bafyreigyhuyz6ojoypzijscy3jcexcogghw53sqf4sr7tt5ii7fmvxoycq",
#         "author": {
#             "did": "did:plc:zfjxw2pf7uxjtbapshhepiw7",
#             "handle": "ruchomuscleworship.bsky.social",
#             "displayName": "Rubén Darío",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:zfjxw2pf7uxjtbapshhepiw7/bafkreies32fwjzytx3wa6s7yspdjeofeis6ffbnkgnwa33ljyl7ixxmwlq@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2025-03-31T01:35:41.893Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:56:32.014Z",
#             "embed": {
#                 "$type": "app.bsky.embed.images",
#                 "images": [
#                     {
#                         "alt": "",
#                         "aspectRatio": {
#                             "height": 935,
#                             "width": 526
#                         },
#                         "image": {
#                             "$type": "blob",
#                             "ref": {
#                                 "$link": "bafkreiftami7appeidebeqs26aye7m7f5sy6umrquitgvdnslejxcefkfe"
#                             },
#                             "mimeType": "image/jpeg",
#                             "size": 278317
#                         }
#                     }
#                 ]
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "Israel OG\n🖼️\nSoy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras.\n ⁣\n   ☯️     Fiódor Dostoievski"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.images#view",
#             "images": [
#                 {
#                     "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:zfjxw2pf7uxjtbapshhepiw7/bafkreiftami7appeidebeqs26aye7m7f5sy6umrquitgvdnslejxcefkfe@jpeg",
#                     "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:zfjxw2pf7uxjtbapshhepiw7/bafkreiftami7appeidebeqs26aye7m7f5sy6umrquitgvdnslejxcefkfe@jpeg",
#                     "alt": "",
#                     "aspectRatio": {
#                         "height": 935,
#                         "width": 526
#                     }
#                 }
#             ]
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:56:36.249Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:a7qkjpjf2e7f2fmeq6yj3l5o/app.bsky.feed.post/3lpda62mygs2h",
#         "cid": "bafyreiheellxojwh5fuli64ey4opfhon6rpvwfhr3tox7j2hbzcucqhvp4",
#         "author": {
#             "did": "did:plc:a7qkjpjf2e7f2fmeq6yj3l5o",
#             "handle": "eci52027646.bsky.social",
#             "displayName": "Manuel Ibáñez",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:a7qkjpjf2e7f2fmeq6yj3l5o/bafkreiggsidwvfmbzz4bdiojqo7r5ixpv63msyblso5pnwkf54dfg6hwmm@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-11-18T16:11:39.004Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:56:31.441Z",
#             "embed": {
#                 "$type": "app.bsky.embed.images",
#                 "images": [
#                     {
#                         "alt": "",
#                         "aspectRatio": {
#                             "height": 2000,
#                             "width": 953
#                         },
#                         "image": {
#                             "$type": "blob",
#                             "ref": {
#                                 "$link": "bafkreif72yubpje3umqaaxztczh3vslghav6jlhkh3qy4koxo2kezb2j6i"
#                             },
#                             "mimeType": "image/jpeg",
#                             "size": 842252
#                         }
#                     }
#                 ]
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo.\nBIEN!!! 👍👍💪🏼🇵🇸"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.images#view",
#             "images": [
#                 {
#                     "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:a7qkjpjf2e7f2fmeq6yj3l5o/bafkreif72yubpje3umqaaxztczh3vslghav6jlhkh3qy4koxo2kezb2j6i@jpeg",
#                     "fullsize": "https://cdn.bsky.app/img/feed_fullsize/plain/did:plc:a7qkjpjf2e7f2fmeq6yj3l5o/bafkreif72yubpje3umqaaxztczh3vslghav6jlhkh3qy4koxo2kezb2j6i@jpeg",
#                     "alt": "",
#                     "aspectRatio": {
#                         "height": 2000,
#                         "width": 953
#                     }
#                 }
#             ]
#         },
#         "replyCount": 0,
#         "repostCount": 1,
#         "likeCount": 1,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:56:38.553Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:56wzdqfa6uhukoniiu5y6cws/app.bsky.feed.post/3lpd7xe5kkk2l",
#         "cid": "bafyreidxt6i7wkjjkbrqg45serjfi7bjn57sqnplzq6xomjthrwamuckku",
#         "author": {
#             "did": "did:plc:56wzdqfa6uhukoniiu5y6cws",
#             "handle": "carlosrolling.bsky.social",
#             "displayName": "Carlos Rolling",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:56wzdqfa6uhukoniiu5y6cws/bafkreidtcjd5zvz6geagl36ia56xykaa4qsyiahewsas36xlk6rabpjrti@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2023-10-16T12:40:25.142Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:52:46.559Z",
#             "embed": {
#                 "$type": "app.bsky.embed.record",
#                 "record": {
#                     "cid": "bafyreie7jhxyho3ek7ukuz25ryei47ftcw622wenegwzrbjmcla3w5lyai",
#                     "uri": "at://did:plc:7f3gemmhvdk6l76aegva6krk/app.bsky.feed.post/3lpcngwyfqk2y"
#                 }
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "Si después de esto no betan a Israel ojalá y nos retiremos. Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas."
#         },
#         "embed": {
#             "$type": "app.bsky.embed.record#view",
#             "record": {
#                 "$type": "app.bsky.embed.record#viewRecord",
#                 "uri": "at://did:plc:7f3gemmhvdk6l76aegva6krk/app.bsky.feed.post/3lpcngwyfqk2y",
#                 "cid": "bafyreie7jhxyho3ek7ukuz25ryei47ftcw622wenegwzrbjmcla3w5lyai",
#                 "author": {
#                     "did": "did:plc:7f3gemmhvdk6l76aegva6krk",
#                     "handle": "escplus.es",
#                     "displayName": "ESCplus España",
#                     "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:7f3gemmhvdk6l76aegva6krk/bafkreicxrkkrfo4pz3gzpcq2wrejtbhenkfkiti76o3n56aecmuawvry2m@jpeg",
#                     "associated": {
#                         "chat": {
#                             "allowIncoming": "all"
#                         }
#                     },
#                     "viewer": {
#                         "muted": false,
#                         "blockedBy": false
#                     },
#                     "labels": [],
#                     "createdAt": "2023-10-28T18:06:43.297Z"
#                 },
#                 "value": {
#                     "$type": "app.bsky.feed.post",
#                     "createdAt": "2025-05-16T18:21:28.545Z",
#                     "embed": {
#                         "$type": "app.bsky.embed.external",
#                         "external": {
#                             "description": "Julia Varela y Tony Aguilar recordaron a las victimas en Gaza antes de la actuación israelí y apelaron a la “vocación integradora y pacífica” del festival.",
#                             "thumb": {
#                                 "$type": "blob",
#                                 "ref": {
#                                     "$link": "bafkreihyo4hirqxr2yc5l22vvkiad5c4aq4jhl6yz654dseonmho3cno5a"
#                                 },
#                                 "mimeType": "image/jpeg",
#                                 "size": 705164
#                             },
#                             "title": "Eurovisión 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” en la presentación de los comentaristas en la segunda semifinal",
#                             "uri": "https://www.escplus.es/eurovision/2025/eurovision-2025-la-uer-investiga-la-queja-de-israel-contra-rtve-por-declaraciones-politicas-en-la-presentacion-de-los-comentaristas-en-la-segunda-semifinal/"
#                         }
#                     },
#                     "facets": [
#                         {
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#tag",
#                                     "tag": "Eurovision"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 32,
#                                 "byteStart": 21
#                             }
#                         },
#                         {
#                             "$type": "app.bsky.richtext.facet",
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#mention",
#                                     "did": "did:plc:af5olnewg5cbichbe5b3bbkz"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 283,
#                                 "byteStart": 258
#                             }
#                         }
#                     ],
#                     "langs": [
#                         "es"
#                     ],
#                     "text": "🆕 Novedades\n\n🚨 #Eurovision 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” \n\n📺 Los comentaristas recordaron a las victimas en Gaza y apelaron a la “vocación integradora y pacífica” del festival\n\n✍️ @josemiguelml.bsky.social"
#                 },
#                 "labels": [],
#                 "likeCount": 13,
#                 "replyCount": 3,
#                 "repostCount": 5,
#                 "quoteCount": 26,
#                 "indexedAt": "2025-05-16T18:21:31.553Z",
#                 "embeds": [
#                     {
#                         "$type": "app.bsky.embed.external#view",
#                         "external": {
#                             "uri": "https://www.escplus.es/eurovision/2025/eurovision-2025-la-uer-investiga-la-queja-de-israel-contra-rtve-por-declaraciones-politicas-en-la-presentacion-de-los-comentaristas-en-la-segunda-semifinal/",
#                             "title": "Eurovisión 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” en la presentación de los comentaristas en la segunda semifinal",
#                             "description": "Julia Varela y Tony Aguilar recordaron a las victimas en Gaza antes de la actuación israelí y apelaron a la “vocación integradora y pacífica” del festival.",
#                             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:7f3gemmhvdk6l76aegva6krk/bafkreihyo4hirqxr2yc5l22vvkiad5c4aq4jhl6yz654dseonmho3cno5a@jpeg"
#                         }
#                     }
#                 ]
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 1,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:52:47.250Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:577dlwgrhycxgclpthwyt2v4/app.bsky.feed.post/3lpd7keqxbk2r",
#         "cid": "bafyreiehja5r7yfaejuut3aarpewrbq5mf7krqjjyxzose4gvhypjvjoam",
#         "author": {
#             "did": "did:plc:577dlwgrhycxgclpthwyt2v4",
#             "handle": "hugoaquino.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:577dlwgrhycxgclpthwyt2v4/bafkreias6mbxr7w4jqd3ildr76ykenw32bm2bgvavm2wz6ja6qp55qzsg4@jpeg",
#             "associated": {
#                 "chat": {
#                     "allowIncoming": "all"
#                 }
#             },
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-11-19T14:43:46.604Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:45:30.999Z",
#             "embed": {
#                 "$type": "app.bsky.embed.video",
#                 "aspectRatio": {
#                     "height": 360,
#                     "width": 638
#                 },
#                 "video": {
#                     "$type": "blob",
#                     "ref": {
#                         "$link": "bafkreibc4qihhaqqwgd4hvp7gsivjnfvvl3qvagkhb5doadqvah5y6ervu"
#                     },
#                     "mimeType": "video/mp4",
#                     "size": 6199368
#                 }
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "EEUU.\nLo detuvieron porque está contra Israel.\nEl genocidio en gaza."
#         },
#         "embed": {
#             "$type": "app.bsky.embed.video#view",
#             "cid": "bafkreibc4qihhaqqwgd4hvp7gsivjnfvvl3qvagkhb5doadqvah5y6ervu",
#             "playlist": "https://video.bsky.app/watch/did%3Aplc%3A577dlwgrhycxgclpthwyt2v4/bafkreibc4qihhaqqwgd4hvp7gsivjnfvvl3qvagkhb5doadqvah5y6ervu/playlist.m3u8",
#             "thumbnail": "https://video.bsky.app/watch/did%3Aplc%3A577dlwgrhycxgclpthwyt2v4/bafkreibc4qihhaqqwgd4hvp7gsivjnfvvl3qvagkhb5doadqvah5y6ervu/thumbnail.jpg",
#             "aspectRatio": {
#                 "height": 360,
#                 "width": 638
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:45:32.746Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:ylbwcwwbjxqrzsqsqlqddkam/app.bsky.feed.post/3lpd7fbowpk2c",
#         "cid": "bafyreicl3kdh256gg5o7dxq6pbgb6czkh6vj2f64hruqnut7cqb2uedosi",
#         "author": {
#             "did": "did:plc:ylbwcwwbjxqrzsqsqlqddkam",
#             "handle": "einereiner71.bsky.social",
#             "displayName": ".ñ.",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:ylbwcwwbjxqrzsqsqlqddkam/bafkreifpod3aokc6cpo6i4xohfwzomilpuqmtsq2d5trbolavcf67pblii@jpeg",
#             "associated": {
#                 "chat": {
#                     "allowIncoming": "following"
#                 }
#             },
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:ylbwcwwbjxqrzsqsqlqddkam",
#                     "uri": "at://did:plc:ylbwcwwbjxqrzsqsqlqddkam/app.bsky.actor.profile/self",
#                     "cid": "bafyreidns2fgh4v2ewntfii7t2zrefy3zcnp7twayok7nfbqp6aqa2bvkm",
#                     "val": "!no-unauthenticated",
#                     "cts": "1970-01-01T00:00:00.000Z"
#                 }
#             ],
#             "createdAt": "2023-10-21T19:33:01.246Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:42:40.015Z",
#             "langs": [
#                 "es"
#             ],
#             "text": "España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio."
#         },
#         "replyCount": 1,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:42:41.949Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:tdi5hsgcoipyzvav4uprktqs/app.bsky.feed.post/3lpd6vicoyk2z",
#         "cid": "bafyreignrwpe2iu223homsdx4qpchdht23fpeqbmuhwbvh3qkkef2ormvy",
#         "author": {
#             "did": "did:plc:tdi5hsgcoipyzvav4uprktqs",
#             "handle": "sjoyner1965.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:tdi5hsgcoipyzvav4uprktqs/bafkreif6i6pdgvmjoam42apzhzmw7fmbaoql4mq5kzhea332drbub2wnre@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:tdi5hsgcoipyzvav4uprktqs",
#                     "uri": "at://did:plc:tdi5hsgcoipyzvav4uprktqs/app.bsky.actor.profile/self",
#                     "cid": "bafyreiawrbgmnualolpx65jsnubdj27pyjedp2rksg2agisoheh2np3uq4",
#                     "val": "!no-unauthenticated",
#                     "cts": "2024-11-15T03:03:23.414Z"
#                 }
#             ],
#             "createdAt": "2024-11-15T03:03:24.142Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:33:50.073Z",
#             "langs": [
#                 "ab",
#                 "en",
#                 "es"
#             ],
#             "reply": {
#                 "parent": {
#                     "cid": "bafyreieeap4jqyxpvhl5a2gr7o773fpuvqkx44y3dhukec5fpnpmf43vsq",
#                     "uri": "at://did:plc:kltyulouaxj5fzco62m3wlih/app.bsky.feed.post/3lpd6id7rq22x"
#                 },
#                 "root": {
#                     "cid": "bafyreihokuzht3e4clmmbgo7cvwu2uofs62mlfodjfqzwhz5fnyjp6gwsa",
#                     "uri": "at://did:plc:3yznbxtrdkjbqqofgdgnzmen/app.bsky.feed.post/3lp5dz3akic2n"
#                 }
#             },
#             "text": "There probably will be. Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist."
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:33:50.250Z",
#         "viewer": {
#             "threadMuted": false,
#             "replyDisabled": true,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:vqc3mje5jl74ufd75uzwg52v/app.bsky.feed.post/3lpd6rrsr7224",
#         "cid": "bafyreigqn5bp4cboekswfo2nxmc4nsouku5k3klrleccplocptmsnt4ila",
#         "author": {
#             "did": "did:plc:vqc3mje5jl74ufd75uzwg52v",
#             "handle": "ramses-sartoryx.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:vqc3mje5jl74ufd75uzwg52v/bafkreihm3cnu5izijk2qplohic4vt5ujri7fqzgurcfzpslymbikcwcbj4@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-11-10T00:55:29.286Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:31:45.829Z",
#             "langs": [
#                 "es"
#             ],
#             "reply": {
#                 "parent": {
#                     "cid": "bafyreicud756d6wacaua4sljqcv4dtpgn3hwezofenbilihp5hit47zmfy",
#                     "uri": "at://did:plc:hcycjfxfvec5kz4zsptyzl3f/app.bsky.feed.post/3lpcarzxioc2a"
#                 },
#                 "root": {
#                     "cid": "bafyreicud756d6wacaua4sljqcv4dtpgn3hwezofenbilihp5hit47zmfy",
#                     "uri": "at://did:plc:hcycjfxfvec5kz4zsptyzl3f/app.bsky.feed.post/3lpcarzxioc2a"
#                 }
#             },
#             "text": "Porque aceptan a Israel? Si no tiene nada que ver con Europa. O acaso permiten participar a países no europeos? Pregunto por mi ignorancia"
#         },
#         "replyCount": 1,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:31:48.856Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:jm2o5fpoh6vrirwwt6s6cphl/app.bsky.feed.post/3lpd6rcd2vc26",
#         "cid": "bafyreibp4xbtz5zdqxhv6g3zr5xfrkcnrfj4oa6hsh2cxsk5mdmpa3ozry",
#         "author": {
#             "did": "did:plc:jm2o5fpoh6vrirwwt6s6cphl",
#             "handle": "rossyta.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:jm2o5fpoh6vrirwwt6s6cphl/bafkreigwoamfwaa3hyw5wjtm6j67rt2cwpnwgy2kvphtw3oekyrfpsd7si@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2025-04-06T11:22:30.193Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:31:29.584Z",
#             "embed": {
#                 "$type": "app.bsky.embed.record",
#                 "record": {
#                     "cid": "bafyreig6ppqma2ay6wtseejzyopnlorbrrhkap62kunrh5lueximtuqupy",
#                     "uri": "at://did:plc:mj2puedw66n53u3dv5ay4mbu/app.bsky.feed.post/3lpcmfk4wys27"
#                 }
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "Como siempre Wyoming lo dice más claro imposible. Israel es un país genocida y el que lo apoye es cómplice."
#         },
#         "embed": {
#             "$type": "app.bsky.embed.record#view",
#             "record": {
#                 "$type": "app.bsky.embed.record#viewRecord",
#                 "uri": "at://did:plc:mj2puedw66n53u3dv5ay4mbu/app.bsky.feed.post/3lpcmfk4wys27",
#                 "cid": "bafyreig6ppqma2ay6wtseejzyopnlorbrrhkap62kunrh5lueximtuqupy",
#                 "author": {
#                     "did": "did:plc:mj2puedw66n53u3dv5ay4mbu",
#                     "handle": "hannibal.bsky.social",
#                     "displayName": "Hannibal Lecter 🦋",
#                     "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:mj2puedw66n53u3dv5ay4mbu/bafkreic4dit2iidynvu64txghy5gvqtkhxfsloyyjaein6kyb2y22up3q4@jpeg",
#                     "associated": {
#                         "chat": {
#                             "allowIncoming": "following"
#                         }
#                     },
#                     "viewer": {
#                         "muted": false,
#                         "blockedBy": false
#                     },
#                     "labels": [],
#                     "createdAt": "2023-07-03T17:33:09.221Z"
#                 },
#                 "value": {
#                     "$type": "app.bsky.feed.post",
#                     "createdAt": "2025-05-16T18:02:47.767Z",
#                     "embed": {
#                         "$type": "app.bsky.embed.video",
#                         "aspectRatio": {
#                             "height": 1024,
#                             "width": 576
#                         },
#                         "video": {
#                             "$type": "blob",
#                             "ref": {
#                                 "$link": "bafkreiaddq4ybsuf2snypeya5nr5hq3qk27574xqqtmkli5ezywtkzlr6y"
#                             },
#                             "mimeType": "video/mp4",
#                             "size": 3039860
#                         }
#                     },
#                     "langs": [
#                         "es"
#                     ],
#                     "text": "Así de claro."
#                 },
#                 "labels": [],
#                 "likeCount": 1063,
#                 "replyCount": 23,
#                 "repostCount": 513,
#                 "quoteCount": 17,
#                 "indexedAt": "2025-05-16T18:02:48.953Z",
#                 "embeds": [
#                     {
#                         "$type": "app.bsky.embed.video#view",
#                         "cid": "bafkreiaddq4ybsuf2snypeya5nr5hq3qk27574xqqtmkli5ezywtkzlr6y",
#                         "playlist": "https://video.bsky.app/watch/did%3Aplc%3Amj2puedw66n53u3dv5ay4mbu/bafkreiaddq4ybsuf2snypeya5nr5hq3qk27574xqqtmkli5ezywtkzlr6y/playlist.m3u8",
#                         "thumbnail": "https://video.bsky.app/watch/did%3Aplc%3Amj2puedw66n53u3dv5ay4mbu/bafkreiaddq4ybsuf2snypeya5nr5hq3qk27574xqqtmkli5ezywtkzlr6y/thumbnail.jpg",
#                         "aspectRatio": {
#                             "height": 1024,
#                             "width": 576
#                         }
#                     }
#                 ]
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:31:30.445Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:i53e6y3liw2oaw4s6e6odw5m/app.bsky.feed.post/3lpd6huqeno2g",
#         "cid": "bafyreiakjdotozi4mekvbl6ohbhywyzygzxnd7joz5arvhlmfzztloyy2m",
#         "author": {
#             "did": "did:plc:i53e6y3liw2oaw4s6e6odw5m",
#             "handle": "bluesky.awakari.com",
#             "displayName": "Awakari",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:i53e6y3liw2oaw4s6e6odw5m/bafkreicvyjeywe5ph65avri3hzojqocoowoqwh3htd7dlazqgwzsnuyjfy@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2025-04-30T15:30:35.574Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:26:13Z",
#             "embed": {
#                 "$type": "app.bsky.embed.external",
#                 "external": {
#                     "description": "Origin",
#                     "title": "",
#                     "uri": "https://www.elmundo.es/internacional/2025/05/16/682783bbe4d4d85b1f8b4598.html"
#                 }
#             },
#             "facets": [
#                 {
#                     "features": [
#                         {
#                             "$type": "app.bsky.richtext.facet#link",
#                             "uri": "https://awakari.com/pub-msg.html?id=TB59LWfaeptHLij6yjNYJQbU7vs&interestId=Trump"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 267,
#                         "byteStart": 260
#                     }
#                 },
#                 {
#                     "features": [
#                         {
#                             "$type": "app.bsky.richtext.facet#link",
#                             "uri": "https://awakari.com/sub-details.html?id=Trump"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 278,
#                         "byteStart": 270
#                     }
#                 },
#                 {
#                     "features": [
#                         {
#                             "$type": "app.bsky.richtext.facet#link",
#                             "uri": "https://bsky.app/profile/did:plc:i53e6y3liw2oaw4s6e6odw5m/feed/Trump"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 285,
#                         "byteStart": 281
#                     }
#                 }
#             ],
#             "labels": {
#                 "$type": "com.atproto.label.defs#selfLabels",
#                 "values": [
#                     {
#                         "val": "Trump"
#                     }
#                 ]
#             },
#             "langs": [
#                 "es"
#             ],
#             "tags": [
#                 "Israel",
#                 "Franja",
#                 "de",
#                 "Gaza",
#                 "Yemen",
#                 "Donald",
#                 "Trump",
#                 "Guerra"
#             ],
#             "text": "Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia  Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye...\n\n| Details | Interest | Feed |"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.external#view",
#             "external": {
#                 "uri": "https://www.elmundo.es/internacional/2025/05/16/682783bbe4d4d85b1f8b4598.html",
#                 "title": "",
#                 "description": "Origin"
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:26:13.849Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": [
#             {
#                 "src": "did:plc:i53e6y3liw2oaw4s6e6odw5m",
#                 "uri": "at://did:plc:i53e6y3liw2oaw4s6e6odw5m/app.bsky.feed.post/3lpd6huqeno2g",
#                 "cid": "bafyreiakjdotozi4mekvbl6ohbhywyzygzxnd7joz5arvhlmfzztloyy2m",
#                 "val": "Trump",
#                 "cts": "2025-05-16T23:26:13.000Z"
#             }
#         ]
#     },
#     {
#         "uri": "at://did:plc:iue6yrpqgmcfanyknm7riffq/app.bsky.feed.post/3lpd6hi5b7k2p",
#         "cid": "bafyreiferfgyo2ff7fbh34tpy5hnqz42zb23bamcyh3hizd7zqm2t6sl7e",
#         "author": {
#             "did": "did:plc:iue6yrpqgmcfanyknm7riffq",
#             "handle": "anasbartolome.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:iue6yrpqgmcfanyknm7riffq/bafkreiboj7prcc4xmdcld2epystl6djb2uvvj2rfxantjxtllkikv6tzma@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2025-03-03T20:22:27.145Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:26:00.142Z",
#             "embed": {
#                 "$type": "app.bsky.embed.external",
#                 "external": {
#                     "description": "La joven Yuval Raphael debuta en la competición durante la segunda semifinal del certamen, mientras que la televisión pública de su país denuncia ante la UER “el acoso” a su representante",
#                     "thumb": {
#                         "$type": "blob",
#                         "ref": {
#                             "$link": "bafkreifexiejoyng5zb64zxeayms4zsbf2l5easszs5vlfoqdelctotd5m"
#                         },
#                         "mimeType": "image/jpeg",
#                         "size": 389439
#                     },
#                     "title": "Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas",
#                     "uri": "https://search.app/xfN3C"
#                 }
#             },
#             "facets": [
#                 {
#                     "features": [
#                         {
#                             "$type": "app.bsky.richtext.facet#link",
#                             "uri": "https://search.app/xfN3C"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 128,
#                         "byteStart": 112
#                     }
#                 }
#             ],
#             "langs": [
#                 "es"
#             ],
#             "text": "Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas\n\nFuente: EL PAÍS\n search.app/xfN3C\n\nCompartido mediante la aplicación Google"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.external#view",
#             "external": {
#                 "uri": "https://search.app/xfN3C",
#                 "title": "Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas",
#                 "description": "La joven Yuval Raphael debuta en la competición durante la segunda semifinal del certamen, mientras que la televisión pública de su país denuncia ante la UER “el acoso” a su representante",
#                 "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:iue6yrpqgmcfanyknm7riffq/bafkreifexiejoyng5zb64zxeayms4zsbf2l5easszs5vlfoqdelctotd5m@jpeg"
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:26:06.648Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:ohoqxnsplsnvhjitq2xc3r6z/app.bsky.feed.post/3lpd6aciow223",
#         "cid": "bafyreic5buikn6xtdano6hokgo5dige5nxlaaqzmnni2ok5iqleilfleva",
#         "author": {
#             "did": "did:plc:ohoqxnsplsnvhjitq2xc3r6z",
#             "handle": "natbrezina.bsky.social",
#             "displayName": "Natalia Brezina  ⛱  ȺᏒ",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:ohoqxnsplsnvhjitq2xc3r6z/bafkreibf5xluftmunhkgpunxjvbkkjqo4knuz75axgqg2n7hjqbowdk34i@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:ohoqxnsplsnvhjitq2xc3r6z",
#                     "uri": "at://did:plc:ohoqxnsplsnvhjitq2xc3r6z/app.bsky.actor.profile/self",
#                     "cid": "bafyreie4c7h3d24gtlvcupul5fuvbv7dfznp2mlvziy4bcucx2ip23xvxe",
#                     "val": "!no-unauthenticated",
#                     "cts": "2024-10-20T22:23:44.155Z"
#                 }
#             ],
#             "createdAt": "2024-10-20T22:23:46.308Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:21:59.345Z",
#             "langs": [
#                 "es"
#             ],
#             "reply": {
#                 "parent": {
#                     "cid": "bafyreifprljjrzv4ud6ugqofvaattoiuvdphezzvqo4ckowwcgnmp3p2em",
#                     "uri": "at://did:plc:t57caw3uaz7kcxt2zidro3ct/app.bsky.feed.post/3lpd65fqhjc2g"
#                 },
#                 "root": {
#                     "cid": "bafyreieao6jsaz6z7y5k7k4eatbcyxowgzcit2nfggoipssegkunnhzcn4",
#                     "uri": "at://did:plc:t57caw3uaz7kcxt2zidro3ct/app.bsky.feed.post/3lpd4wuvpos2g"
#                 }
#             },
#             "text": "Se ve que son parientes. Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina. Y el chabón es polaco. Que basura sionista por favor. Mierda sionista. Como el comehermana."
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:22:07.545Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:577dlwgrhycxgclpthwyt2v4/app.bsky.feed.post/3lpd64p3yvk2r",
#         "cid": "bafyreicjhyofklan3bka3uob5p6ekz73jkmqa7jra4koijvtt6u5sypk7i",
#         "author": {
#             "did": "did:plc:577dlwgrhycxgclpthwyt2v4",
#             "handle": "hugoaquino.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:577dlwgrhycxgclpthwyt2v4/bafkreias6mbxr7w4jqd3ildr76ykenw32bm2bgvavm2wz6ja6qp55qzsg4@jpeg",
#             "associated": {
#                 "chat": {
#                     "allowIncoming": "all"
#                 }
#             },
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-11-19T14:43:46.604Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T23:19:58.342Z",
#             "embed": {
#                 "$type": "app.bsky.embed.video",
#                 "aspectRatio": {
#                     "height": 480,
#                     "width": 852
#                 },
#                 "video": {
#                     "$type": "blob",
#                     "ref": {
#                         "$link": "bafkreiahwsgg77akoowlssznjphv5btcaoumw7vutjy4dc666usamtd4iy"
#                     },
#                     "mimeType": "video/mp4",
#                     "size": 3882308
#                 }
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "Israel.\nLos judíos nazis asesinos.\nComenzaron el último ataque contra Gaza.\n😡😡😡😡😡😡😡😡"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.video#view",
#             "cid": "bafkreiahwsgg77akoowlssznjphv5btcaoumw7vutjy4dc666usamtd4iy",
#             "playlist": "https://video.bsky.app/watch/did%3Aplc%3A577dlwgrhycxgclpthwyt2v4/bafkreiahwsgg77akoowlssznjphv5btcaoumw7vutjy4dc666usamtd4iy/playlist.m3u8",
#             "thumbnail": "https://video.bsky.app/watch/did%3Aplc%3A577dlwgrhycxgclpthwyt2v4/bafkreiahwsgg77akoowlssznjphv5btcaoumw7vutjy4dc666usamtd4iy/thumbnail.jpg",
#             "aspectRatio": {
#                 "height": 480,
#                 "width": 852
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T23:19:59.946Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:hlrbhkcdwuhlraakzxqqhc2r/app.bsky.feed.post/3lpd5x3244yo2",
#         "cid": "bafyreidsohx2k3efvxnm5xskaipzhn7vl2qrds33xgu5ms3kzukqfjpzqa",
#         "author": {
#             "did": "did:plc:hlrbhkcdwuhlraakzxqqhc2r",
#             "handle": "miguelmaiquez.mastodon.social.ap.brid.gy",
#             "displayName": "Miguel Máiquez",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:hlrbhkcdwuhlraakzxqqhc2r/bafkreia4lx2fu2jer5wnusumuqlf3bdlxvb2sjjurugt7r634ifut74if4@jpeg",
#             "associated": {
#                 "chat": {
#                     "allowIncoming": "none"
#                 }
#             },
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:hlrbhkcdwuhlraakzxqqhc2r",
#                     "uri": "at://did:plc:hlrbhkcdwuhlraakzxqqhc2r/app.bsky.actor.profile/self",
#                     "cid": "bafyreifko34xzdcvzqg5o5wuylnwnqkjlgsetadnfvrgqim2onxux3ubxa",
#                     "val": "bridged-from-bridgy-fed-activitypub",
#                     "cts": "1970-01-01T00:00:00.000Z"
#                 }
#             ],
#             "createdAt": "2024-11-15T05:39:36.051Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "bridgyOriginalText": "<p>Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre</p><p><a href=\"https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html\" target=\"_blank\" rel=\"nofollow noopener\" translate=\"no\"><span class=\"invisible\">https://</span><span class=\"ellipsis\">elpais.com/internacional/2025-</span><span class=\"invisible\">05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html</span></a></p><p><a href=\"https://mastodon.social/tags/Israel\" class=\"mention hashtag\" rel=\"tag\">#<span>Israel</span></a> <a href=\"https://mastodon.social/tags/Gaza\" class=\"mention hashtag\" rel=\"tag\">#<span>Gaza</span></a></p>",
#             "bridgyOriginalUrl": "https://mastodon.social/@miguelmaiquez/114520057925333394",
#             "createdAt": "2025-05-16T23:16:47.000Z",
#             "embed": {
#                 "$type": "app.bsky.embed.external",
#                 "external": {
#                     "$type": "app.bsky.embed.external#external",
#                     "description": "Trump dice que Estados Unidos va a “ocuparse” de la Franja porque “mucha gente se está muriendo de hambre”. El ejército israelí ordena la evacuación de zonas del norte de Gaza",
#                     "thumb": {
#                         "$type": "blob",
#                         "ref": {
#                             "$link": "bafkreifydtffrppvwhtfeirlxmmisydbbov23mu43ioiciqq2zdaqabuhe"
#                         },
#                         "mimeType": "image/jpeg",
#                         "size": 106099
#                     },
#                     "title": "Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre",
#                     "uri": "https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html"
#                 }
#             },
#             "facets": [
#                 {
#                     "$type": "app.bsky.richtext.facet",
#                     "features": [
# ...
#                             "uri": "https://agraciablog.wordpress.com/2025/05/16/los-artistas-se-plantan-frente-a-los-festivales-propiedad-del-fondo-kkr-con-intereses-en-israel/"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 139,
#                         "byteStart": 98
#                     }
#                 }
#             ],
#             "langs": [
#                 "es"
#             ],
#             "text": "Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel. agraciablog.wordpress.com/2025/05/16/l..."
#         },
#         "embed": {
#             "$type": "app.bsky.embed.external#view",
#             "external": {
#                 "uri": "https://agraciablog.wordpress.com/2025/05/16/los-artistas-se-plantan-frente-a-los-festivales-propiedad-del-fondo-kkr-con-intereses-en-israel/",
#                 "title": "Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel.",
#                 "description": "Grandes citas musicales de nuestro país como ViñaRock o el Sónar han sido adquiridos por este gigante financiero y numerosos músicos – como Fermin Muguruza, Reincidentes, Sons of Aguirre o Sí…",
#                 "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:wy22l7wn6bvawvsbn2spmtss/bafkreiga3a5dkp4wvaxx7b6j2k2x3hzrfilckjj7cdiwapqezxivjxd4pe@jpeg"
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 1,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T22:48:49.151Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:nuu2n42zfvdtcj6oq6bjyktj/app.bsky.feed.post/3lpd4damsbc25",
#         "cid": "bafyreifsixo2tfcunxh4fr6tfov6s4b4les6xzgjaisg6tonlhl6cbumvy",
#         "author": {
#             "did": "did:plc:nuu2n42zfvdtcj6oq6bjyktj",
#             "handle": "nachomontesdeoca.bsky.social",
#             "displayName": "Nacho Montes de Oca",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:nuu2n42zfvdtcj6oq6bjyktj/bafkreigo3powlpbzenxbibkvdnixo37ygh2q4bocwwwdhz2vtl2m5s4aoe@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:nuu2n42zfvdtcj6oq6bjyktj",
#                     "uri": "at://did:plc:nuu2n42zfvdtcj6oq6bjyktj/app.bsky.actor.profile/self",
#                     "cid": "bafyreidnkhl7f7wsbijgh73w242qgtqxcmhqoa5ofahrvjrwzc2pl6arfy",
#                     "val": "!no-unauthenticated",
#                     "cts": "2024-11-13T22:34:03.244Z"
#                 }
#             ],
#             "createdAt": "2024-11-13T22:34:05.182Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T22:47:50.562Z",
#             "langs": [
#                 "es"
#             ],
#             "reply": {
#                 "parent": {
#                     "cid": "bafyreidmtpmjhcwa5cgblk3ka5wgcz7wm3iaqkttjf72eic4warsyzbzdy",
#                     "uri": "at://did:plc:nuu2n42zfvdtcj6oq6bjyktj/app.bsky.feed.post/3lpd3xzzefk25"
#                 },
#                 "root": {
#                     "cid": "bafyreids7gxkybzeflhng5sj53tcbes3kkpavmscjjaasrve2i4h3fr2au",
#                     "uri": "at://did:plc:nuu2n42zfvdtcj6oq6bjyktj/app.bsky.feed.post/3lpd3whwhgk25"
#                 }
#             },
#             "text": "Tal como había prometido Netanyahu, iba a esperar los resultados de la gira del presidente de EEUU por los países árabes antes de tomar una decisión respecto a la ofensiva\nIsrael define su propia agenda y comienza el intento definitivo para definir el futuro inmediato de Gaza"
#         },
#         "replyCount": 1,
#         "repostCount": 1,
#         "likeCount": 5,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T22:47:51.848Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:isp6evip4int3sl2kvhpcl6p/app.bsky.feed.post/3lpd47xhvj22g",
#         "cid": "bafyreigutswtoedoy5llk6rgfq4pwgcw5m2hoxxsxc4uhargi77bonsof4",
#         "author": {
#             "did": "did:plc:isp6evip4int3sl2kvhpcl6p",
#             "handle": "josi231.bsky.social",
#             "displayName": "",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:isp6evip4int3sl2kvhpcl6p/bafkreidos3kla34dgiitt46lltmgsubchrgc7ex5vrziyxgxiukqguxraq@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [],
#             "createdAt": "2024-10-17T15:25:34.606Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T22:46:00.300Z",
#             "embed": {
#                 "$type": "app.bsky.embed.external",
#                 "external": {
#                     "description": "Ya no queda casi nada para el festival de música de Eurovisión, en el que Israel estará en la final.",
#                     "thumb": {
#                         "$type": "blob",
#                         "ref": {
#                             "$link": "bafkreibmvj3ivts43bfc5srlwbkyp5ig25cxohwj5rfdgr5aysl6i6nd5q"
#                         },
#                         "mimeType": "image/jpeg",
#                         "size": 322640
#                     },
#                     "title": "Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: \"Había más posibilidades que no participara por una canción que por un genocidio\"",
#                     "uri": "https://www.publico.es/tremending/buenafuente-lleva-todos-aplausos-criticar-israel-eurovision-habia-posibilidades-participara-cancion-genocidio.html?utm_source=piano&utm_medium=newsletter&utm_campaign=captacion&utm_content=tremending&segment=registrados&tpcc=nl_tremendingreg0425&pnespid=VuExpBtQuD4Rkk6K55.dRkJHuhwy0u95tQNNBLMSK8zK3UlbVjdyWOfxN5ox7sHsu1fmvvZV"
#                 }
#             },
#             "facets": [
#                 {
#                     "features": [
#                         {
#                             "$type": "app.bsky.richtext.facet#link",
#                             "uri": "https://www.publico.es/tremending/buenafuente-lleva-todos-aplausos-criticar-israel-eurovision-habia-posibilidades-participara-cancion-genocidio.html?utm_source=piano&utm_medium=newsletter&utm_campaign=captacion&utm_content=tremending&segment=registrados&tpcc=nl_tremendingreg0425&pnespid=VuExpBtQuD4Rkk6K55.dRkJHuhwy0u95tQNNBLMSK8zK3UlbVjdyWOfxN5ox7sHsu1fmvvZV"
#                         }
#                     ],
#                     "index": {
#                         "byteEnd": 195,
#                         "byteStart": 165
#                     }
#                 }
#             ],
#             "langs": [
#                 "es"
#             ],
#             "text": "Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: \"Había más posibilidades que no participara por una canción que por un genocidio\" \nwww.publico.es/tremending/b..."
#         },
#         "embed": {
#             "$type": "app.bsky.embed.external#view",
#             "external": {
#                 "uri": "https://www.publico.es/tremending/buenafuente-lleva-todos-aplausos-criticar-israel-eurovision-habia-posibilidades-participara-cancion-genocidio.html?utm_source=piano&utm_medium=newsletter&utm_campaign=captacion&utm_content=tremending&segment=registrados&tpcc=nl_tremendingreg0425&pnespid=VuExpBtQuD4Rkk6K55.dRkJHuhwy0u95tQNNBLMSK8zK3UlbVjdyWOfxN5ox7sHsu1fmvvZV",
#                 "title": "Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: \"Había más posibilidades que no participara por una canción que por un genocidio\"",
#                 "description": "Ya no queda casi nada para el festival de música de Eurovisión, en el que Israel estará en la final.",
#                 "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:isp6evip4int3sl2kvhpcl6p/bafkreibmvj3ivts43bfc5srlwbkyp5ig25cxohwj5rfdgr5aysl6i6nd5q@jpeg"
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 0,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T22:46:02.144Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     },
#     {
#         "uri": "at://did:plc:nq2qap2liozwqt6abk24d6xw/app.bsky.feed.post/3lpd45jx4qk2f",
#         "cid": "bafyreibyimrdhafb7yfe5aq7m44dzha64ytbfjepyw2pvo4oyysoutmygq",
#         "author": {
#             "did": "did:plc:nq2qap2liozwqt6abk24d6xw",
#             "handle": "ivanef24.bsky.social",
#             "displayName": "Ivan✌🏼",
#             "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:nq2qap2liozwqt6abk24d6xw/bafkreidnwzujtzv5cnniatyj5jddqm2iwhuj6ncuw3pjvvi6rzg67q7flm@jpeg",
#             "viewer": {
#                 "muted": false,
#                 "blockedBy": false
#             },
#             "labels": [
#                 {
#                     "src": "did:plc:nq2qap2liozwqt6abk24d6xw",
#                     "uri": "at://did:plc:nq2qap2liozwqt6abk24d6xw/app.bsky.actor.profile/self",
#                     "cid": "bafyreida44uwdxq2tofo3u2fdcv43djzmr3pvrkdfdp2daqfd36wu3vbji",
#                     "val": "!no-unauthenticated",
#                     "cts": "2024-11-14T21:40:17.773Z"
#                 }
#             ],
#             "createdAt": "2024-11-14T21:40:18.245Z"
#         },
#         "record": {
#             "$type": "app.bsky.feed.post",
#             "createdAt": "2025-05-16T22:44:39.011Z",
#             "embed": {
#                 "$type": "app.bsky.embed.record",
#                 "record": {
#                     "cid": "bafyreie7jhxyho3ek7ukuz25ryei47ftcw622wenegwzrbjmcla3w5lyai",
#                     "uri": "at://did:plc:7f3gemmhvdk6l76aegva6krk/app.bsky.feed.post/3lpcngwyfqk2y"
#                 }
#             },
#             "langs": [
#                 "es"
#             ],
#             "text": "Es que me lo veía venir, a ver si mañana actuamos, y en el caso de que sea así tened clarisimo que quedamos últimos.\n\nPara la próxima edición sinceramente que salgan de Eurovision los países del big 5, y todos los que estén en contra de que este ahí Israel.\n\nY que le den a la UER"
#         },
#         "embed": {
#             "$type": "app.bsky.embed.record#view",
#             "record": {
#                 "$type": "app.bsky.embed.record#viewRecord",
#                 "uri": "at://did:plc:7f3gemmhvdk6l76aegva6krk/app.bsky.feed.post/3lpcngwyfqk2y",
#                 "cid": "bafyreie7jhxyho3ek7ukuz25ryei47ftcw622wenegwzrbjmcla3w5lyai",
#                 "author": {
#                     "did": "did:plc:7f3gemmhvdk6l76aegva6krk",
#                     "handle": "escplus.es",
#                     "displayName": "ESCplus España",
#                     "avatar": "https://cdn.bsky.app/img/avatar/plain/did:plc:7f3gemmhvdk6l76aegva6krk/bafkreicxrkkrfo4pz3gzpcq2wrejtbhenkfkiti76o3n56aecmuawvry2m@jpeg",
#                     "associated": {
#                         "chat": {
#                             "allowIncoming": "all"
#                         }
#                     },
#                     "viewer": {
#                         "muted": false,
#                         "blockedBy": false
#                     },
#                     "labels": [],
#                     "createdAt": "2023-10-28T18:06:43.297Z"
#                 },
#                 "value": {
#                     "$type": "app.bsky.feed.post",
#                     "createdAt": "2025-05-16T18:21:28.545Z",
#                     "embed": {
#                         "$type": "app.bsky.embed.external",
#                         "external": {
#                             "description": "Julia Varela y Tony Aguilar recordaron a las victimas en Gaza antes de la actuación israelí y apelaron a la “vocación integradora y pacífica” del festival.",
#                             "thumb": {
#                                 "$type": "blob",
#                                 "ref": {
#                                     "$link": "bafkreihyo4hirqxr2yc5l22vvkiad5c4aq4jhl6yz654dseonmho3cno5a"
#                                 },
#                                 "mimeType": "image/jpeg",
#                                 "size": 705164
#                             },
#                             "title": "Eurovisión 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” en la presentación de los comentaristas en la segunda semifinal",
#                             "uri": "https://www.escplus.es/eurovision/2025/eurovision-2025-la-uer-investiga-la-queja-de-israel-contra-rtve-por-declaraciones-politicas-en-la-presentacion-de-los-comentaristas-en-la-segunda-semifinal/"
#                         }
#                     },
#                     "facets": [
#                         {
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#tag",
#                                     "tag": "Eurovision"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 32,
#                                 "byteStart": 21
#                             }
#                         },
#                         {
#                             "$type": "app.bsky.richtext.facet",
#                             "features": [
#                                 {
#                                     "$type": "app.bsky.richtext.facet#mention",
#                                     "did": "did:plc:af5olnewg5cbichbe5b3bbkz"
#                                 }
#                             ],
#                             "index": {
#                                 "byteEnd": 283,
#                                 "byteStart": 258
#                             }
#                         }
#                     ],
#                     "langs": [
#                         "es"
#                     ],
#                     "text": "🆕 Novedades\n\n🚨 #Eurovision 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” \n\n📺 Los comentaristas recordaron a las victimas en Gaza y apelaron a la “vocación integradora y pacífica” del festival\n\n✍️ @josemiguelml.bsky.social"
#                 },
#                 "labels": [],
#                 "likeCount": 13,
#                 "replyCount": 3,
#                 "repostCount": 5,
#                 "quoteCount": 26,
#                 "indexedAt": "2025-05-16T18:21:31.553Z",
#                 "embeds": [
#                     {
#                         "$type": "app.bsky.embed.external#view",
#                         "external": {
#                             "uri": "https://www.escplus.es/eurovision/2025/eurovision-2025-la-uer-investiga-la-queja-de-israel-contra-rtve-por-declaraciones-politicas-en-la-presentacion-de-los-comentaristas-en-la-segunda-semifinal/",
#                             "title": "Eurovisión 2025: La UER investiga la queja de Israel contra RTVE por “declaraciones políticas” en la presentación de los comentaristas en la segunda semifinal",
#                             "description": "Julia Varela y Tony Aguilar recordaron a las victimas en Gaza antes de la actuación israelí y apelaron a la “vocación integradora y pacífica” del festival.",
#                             "thumb": "https://cdn.bsky.app/img/feed_thumbnail/plain/did:plc:7f3gemmhvdk6l76aegva6krk/bafkreihyo4hirqxr2yc5l22vvkiad5c4aq4jhl6yz654dseonmho3cno5a@jpeg"
#                         }
#                     }
#                 ]
#             }
#         },
#         "replyCount": 0,
#         "repostCount": 0,
#         "likeCount": 2,
#         "quoteCount": 0,
#         "indexedAt": "2025-05-16T22:44:38.753Z",
#         "viewer": {
#             "threadMuted": false,
#             "embeddingDisabled": false
#         },
#         "labels": []
#     }
# ]

# %% [markdown]
# Aquí facemos unha lista lines coas liñas (cada unha é un *post* de Bluesky)

# %%
lines = []
with (open(file_txt_path,'r')) as file_txt:
  for i in range(limit):
    line = file_txt.readline()
    lines.append(line)
    #lines[i] = line
    print('line', " ", i, " :", line)

print('\n \n')
print(' ============= LIÑAS =============== \n \n \n')
print (lines)
print (lines[23])
# Out:
# line   0  : Tengo ya depresión post-eurovisión, y eso que aún no ha acabado. Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa.  Tampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel.
#
# line   1  : Israel OG 🖼️ Soy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras.  ⁣    ☯️     Fiódor Dostoievski
#
# line   2  : INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo. BIEN!!! 👍👍💪🏼🇵🇸
#
# line   3  : Si después de esto no betan a Israel ojalá y nos retiremos. Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas.
#
# line   4  : EEUU. Lo detuvieron porque está contra Israel. El genocidio en gaza.
#
# line   5  : España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio.
#
# line   6  : There probably will be. Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist.
#
# line   7  : Porque aceptan a Israel? Si no tiene nada que ver con Europa. O acaso permiten participar a países no europeos? Pregunto por mi ignorancia
#
# line   8  : Como siempre Wyoming lo dice más claro imposible. Israel es un país genocida y el que lo apoye es cómplice.
#
# line   9  : Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia  Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye...  | Details | Interest | Feed |
#
# line   10  : Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas  Fuente: EL PAÍS  search.app/xfN3C  Compartido mediante la aplicación Google
#
# line   11  : Se ve que son parientes. Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina. Y el chabón es polaco. Que basura sionista por favor. Mierda sionista. Como el comehermana.
#
# line   12  : Israel. Los judíos nazis asesinos. Comenzaron el último ataque contra Gaza. 😡😡😡😡😡😡😡😡
#
# line   13  : Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza
#
# line   14  : Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza
#
# line   15  : BOICOT A ISRAEL!
#
# line   16  : Israel mancha otra final de Eurovisión, bajo la permisividad de la UER a su TV pública y con nueva amenaza de victoria www.eldiario.es/vertele/1_bb...
#
# line   17  : Fermin Muguruza, Reincidentes y decenas de artistas rechazan actuar en festivales propiedad del fondo con intereses en Israel KKR  Fuente: elDiario.es  search.app/pocDb  Compartido mediante la aplicación Google
#
# line   18  : Me repito mucho, pero me da igual:  No admito críticas por ver Eurovisión que vengan de peña que ha defendido hasta el último minuto la permanencia de su partido en Sumar y en el Gobierno pese al comercio de armas con Israel.
#
# line   19  : 💥 “ES UNA SITUACIÓN SIN PRECEDENTES” TRUMP DA DURO MENSAJE SOBRE ISRAEL ... youtu.be/DRjnZCBaHd0?... a través de @YouTube
#
# line   20  : 70 artistas, bandas y DJ internacionales exigen al Sónar que se distancie de las inversiones de KKR en Israel. agraciablog.wordpress.com/2025/05/16/7...
#
# line   21  : Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel. agraciablog.wordpress.com/2025/05/16/l...
#
# line   22  : Tal como había prometido Netanyahu, iba a esperar los resultados de la gira del presidente de EEUU por los países árabes antes de tomar una decisión respecto a la ofensiva Israel define su propia agenda y comienza el intento definitivo para definir el futuro inmediato de Gaza
#
# line   23  : Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: "Había más posibilidades que no participara por una canción que por un genocidio"  www.publico.es/tremending/b...
#
# line   24  : Es que me lo veía venir, a ver si mañana actuamos, y en el caso de que sea así tened clarisimo que quedamos últimos.  Para la próxima edición sinceramente que salgan de Eurovision los países del big 5, y todos los que estén en contra de que este ahí Israel.  Y que le den a la UER
#
#
#
#
#  ============= LIÑAS ===============
#
#
#
# ['Tengo ya depresión post-eurovisión, y eso que aún no ha acabado. Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa.  Tampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel.\n', 'Israel OG 🖼️ Soy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras.  \u2063    ☯️     Fiódor Dostoievski\n', 'INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo. BIEN!!! 👍👍💪🏼🇵🇸\n', 'Si después de esto no betan a Israel ojalá y nos retiremos. Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas.\n', 'EEUU. Lo detuvieron porque está contra Israel. El genocidio en gaza.\n', 'España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio.\n', 'There probably will be. Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist.\n', 'Porque aceptan a Israel? Si no tiene nada que ver con Europa. O acaso permiten participar a países no europeos? Pregunto por mi ignorancia\n', 'Como siempre Wyoming lo dice más claro imposible. Israel es un país genocida y el que lo apoye es cómplice.\n', 'Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia\xa0 Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye...  | Details | Interest | Feed |\n', 'Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas  Fuente: EL PAÍS  search.app/xfN3C  Compartido mediante la aplicación Google\n', 'Se ve que son parientes. Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina. Y el chabón es polaco. Que basura sionista por favor. Mierda sionista. Como el comehermana.\n', 'Israel. Los judíos nazis asesinos. Comenzaron el último ataque contra Gaza. 😡😡😡😡😡😡😡😡\n', 'Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza\n', 'Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html  #Israel #Gaza\n', 'BOICOT A ISRAEL!\n', 'Israel mancha otra final de Eurovisión, bajo la permisividad de la UER a su TV pública y con nueva amenaza de victoria www.eldiario.es/vertele/1_bb...\n', 'Fermin Muguruza, Reincidentes y decenas de artistas rechazan actuar en festivales propiedad del fondo con intereses en Israel KKR  Fuente: elDiario.es  search.app/pocDb  Compartido mediante la aplicación Google\n', 'Me repito mucho, pero me da igual:  No admito críticas por ver Eurovisión que vengan de peña que ha defendido hasta el último minuto la permanencia de su partido en Sumar y en el Gobierno pese al comercio de armas con Israel.\n', '💥 “ES UNA SITUACIÓN SIN PRECEDENTES” TRUMP DA DURO MENSAJE SOBRE ISRAEL ... youtu.be/DRjnZCBaHd0?... a través de @YouTube\n', '70 artistas, bandas y DJ internacionales exigen al Sónar que se distancie de las inversiones de KKR en Israel. agraciablog.wordpress.com/2025/05/16/7...\n', 'Los artistas se plantan frente a los festivales propiedad del fondo KKR, con intereses en Israel. agraciablog.wordpress.com/2025/05/16/l...\n', 'Tal como había prometido Netanyahu, iba a esperar los resultados de la gira del presidente de EEUU por los países árabes antes de tom ...
# Buenafuente se lleva todos los aplausos tras criticar a Israel en Eurovisión: "Había más posibilidades que no participara por una canción que por un genocidio"  www.publico.es/tremending/b...

# %%
import string
#primera = []
#primera = lines[0].split()
#print (primera)

p = 0
f = 0
frases = []
palabras = []
for line in lines:
  frases.append(line.split('.'))
  palabras.append(line.split(' '))
print (frases)


print (palabras)

for fi in range(limit):
  f += len(frases[fi])
print('Número total de frases: ', f)

for pi in range(fi):
  p += len(palabras[pi])

print('Número total de palabras: ', p)
# Out:
# [['Tengo ya depresión post-eurovisión, y eso que aún no ha acabado', ' Estoy tan acostumbrado a venirme abajo después de acontecimientos muy esperados, que ya mi cerebro lo anticipa', '  Tampoco ayuda la sensación enorme de culpa que tengo por ver el festival pese a que apoye y valide a Israel', '\n'], ['Israel OG 🖼️ Soy enemigo de los lugares llenos de gente, de la fanfarronería de dinero y de linaje, de la pretensión, de la gente consumidora, de las relaciones fugaces y de las reuniones llenas de hipocresía y mentiras', '  \u2063    ☯️     Fiódor Dostoievski\n'], ['INFOLIBRE no publicará información sobre el festival de EUROVISIÓN en solidaridad con Gaza y por la participación de Israel en el mismo', ' BIEN!!! 👍👍💪🏼🇵🇸\n'], ['Si después de esto no betan a Israel ojalá y nos retiremos', ' Que el Benidorm Fest continúe pero sin ir a Eurovisión y fin, tendremos nuestro propio festival y sin genocidas', '\n'], ['EEUU', ' Lo detuvieron porque está contra Israel', ' El genocidio en gaza', '\n'], ['España acaba de reconocer que si sigue haciendo negocios con Israel es cómplice de un genocidio', '\n'], ['There probably will be', ' Ime, every person I know whose ancestors escaped pogroms tend to believe Israel as a country should exist', '\n'], ['Porque aceptan a Israel? Si no tiene nada que ver con Europa', ' O acaso permiten participar a países no europeos? Pregunto por mi ignorancia\n'], ['Como siempre Wyoming lo dice más claro imposible', ' Israel es un país genocida y el que lo apoye es cómplice', '\n'], ['Después de que Netanyahu prometiera aumentar la presión sobre Hamas, un funcionario israelí ha avanzado que estos ataques preceden a una operación más amplia\xa0 Leer News & Politics Israel mata a un centenar de personas en Gaza y ataca puertos en Ye', '', '', '  | Details | Interest | Feed |\n'], ['Israel llega a la segunda semifinal de Eurovisión ante las protestas de agrupaciones suizas  Fuente: EL PAÍS  search', 'app/xfN3C  Compartido mediante la aplicación Google\n'], ['Se ve que son parientes', ' Me causa gracia Netanyahu que siempre dice que su familia habitó durante muchas generaciones Israel desde antes que Palestina', ' Y el chabón es polaco', ' Que basura sionista por favor', ' Mierda sionista', ' Como el comehermana', '\n'], ['Israel', ' Los judíos nazis asesinos', ' Comenzaron el último ataque contra Gaza', ' 😡😡😡😡😡😡😡😡\n'], ['Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais', 'com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre', 'html  #Israel #Gaza\n'], ['Israel mata a más de 100 palestinos en Gaza en nuevos ataques mientras prepara otra ofensiva terrestre  https://elpais', 'com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre', 'html  #Israel #Gaza\n'], ['BOICOT A ISRAEL!\n'], ['Israel mancha otra final de Eurovisión, bajo la permisividad de la UER a su TV pública y con nueva amenaza de victoria www', 'eldiario', 'es/vertele/1_bb', '', '', '\n'], ['Fermin Muguruza, Reincidentes y decenas de artistas rechazan actuar en festivales propiedad del fondo con intereses en Israel KKR  Fuente: elDiario', 'es  search', 'app/pocDb  Compartido mediante la aplicación Google\n'], ['Me repito mucho, pero me da igual:  No admito críticas por ver Eurovisión que vengan de peña que ha defendido hasta el último minuto la permanencia de su partido en Sumar y en el Gobierno pese al comercio de armas con Israel', '\n'], ['💥 “ES UNA SITUACIÓN SIN PRECEDENTES” TRUMP DA DURO MENSAJE SOBRE ISRAEL ', '', '', ' youtu', 'be/DRjnZCBaHd0?', '', '', ' a través de @YouTube\n'], ['70 artistas, bandas y DJ internacionales exigen al Sónar que se distancie de las inversiones de KKR en Israel', ' agraciablog', 'wordpress', 'com/2025/05/16/7', '', '', '\n'], ['Los artistas se plantan frente a los festivales propiedad del fondo KKR,  ...
# [['Tengo', 'ya', 'depresión', 'post-eurovisión,', 'y', 'eso', 'que', 'aún', 'no', 'ha', 'acabado.', 'Estoy', 'tan', 'acostumbrado', 'a', 'venirme', 'abajo', 'después', 'de', 'acontecimientos', 'muy', 'esperados,', 'que', 'ya', 'mi', 'cerebro', 'lo', 'anticipa.', '', 'Tampoco', 'ayuda', 'la', 'sensación', 'enorme', 'de', 'culpa', 'que', 'tengo', 'por', 'ver', 'el', 'festival', 'pese', 'a', 'que', 'apoye', 'y', 'valide', 'a', 'Israel.\n'], ['Israel', 'OG', '🖼️', 'Soy', 'enemigo', 'de', 'los', 'lugares', 'llenos', 'de', 'gente,', 'de', 'la', 'fanfarronería', 'de', 'dinero', 'y', 'de', 'linaje,', 'de', 'la', 'pretensión,', 'de', 'la', 'gente', 'consumidora,', 'de', 'las', 'relaciones', 'fugaces', 'y', 'de', 'las', 'reuniones', 'llenas', 'de', 'hipocresía', 'y', 'mentiras.', '', '\u2063', '', '', '', '☯️', '', '', '', '', 'Fiódor', 'Dostoievski\n'], ['INFOLIBRE', 'no', 'publicará', 'información', 'sobre', 'el', 'festival', 'de', 'EUROVISIÓN', 'en', 'solidaridad', 'con', 'Gaza', 'y', 'por', 'la', 'participación', 'de', 'Israel', 'en', 'el', 'mismo.', 'BIEN!!!', '👍👍💪🏼🇵🇸\n'], ['Si', 'después', 'de', 'esto', 'no', 'betan', 'a', 'Israel', 'ojalá', 'y', 'nos', 'retiremos.', 'Que', 'el', 'Benidorm', 'Fest', 'continúe', 'pero', 'sin', 'ir', 'a', 'Eurovisión', 'y', 'fin,', 'tendremos', 'nuestro', 'propio', 'festival', 'y', 'sin', 'genocidas.\n'], ['EEUU.', 'Lo', 'detuvieron', 'porque', 'está', 'contra', 'Israel.', 'El', 'genocidio', 'en', 'gaza.\n'], ['España', 'acaba', 'de', 'reconocer', 'que', 'si', 'sigue', 'haciendo', 'negocios', 'con', 'Israel', 'es', 'cómplice', 'de', 'un', 'genocidio.\n'], ['There', 'probably', 'will', 'be.', 'Ime,', 'every', 'person', 'I', 'know', 'whose', 'ancestors', 'escaped', 'pogroms', 'tend', 'to', 'believe', 'Israel', 'as', 'a', 'country', 'should', 'exist.\n'], ['Porque', 'aceptan', 'a', 'Israel?', 'Si', 'no', 'tiene', 'nada', 'que', 'ver', 'con', 'Europa.', 'O', 'acaso', 'permiten', 'participar', 'a', 'países', 'no', 'europeos?', 'Pregunto', 'por', 'mi', 'ignorancia\n'], ['Como', 'siempre', 'Wyoming', 'lo', 'dice', 'más', 'claro', 'imposible.', 'Israel', 'es', 'un', 'país', 'genocida', 'y', 'el', 'que', 'lo', 'apoye', 'es', 'cómplice.\n'], ['Después', 'de', 'que', 'Netanyahu', 'prometiera', 'aumentar', 'la', 'presión', 'sobre', 'Hamas,', 'un', 'funcionario', 'israelí', 'ha', 'avanzado', 'que', 'estos', 'ataques', 'preceden', 'a', 'una', 'operación', 'más', 'amplia\xa0', 'Leer', 'News', '&', 'Politics', 'Israel', 'mata', 'a', 'un', 'centenar', 'de', 'personas', 'en', 'Gaza', 'y', 'ataca', 'puertos', 'en', 'Ye...', '', '|', 'Details', '|', 'Interest', '|', 'Feed', '|\n'], ['Israel', 'llega', 'a', 'la', 'segunda', 'semifinal', 'de', 'Eurovisión', 'ante', 'las', 'protestas', 'de', 'agrupaciones', 'suizas', '', 'Fuente:', 'EL', 'PAÍS', '', 'search.app/xfN3C', '', 'Compartido', 'mediante', 'la', 'aplicación', 'Google\n'], ['Se', 've', 'que', 'son', 'parientes.', 'Me', 'causa', 'gracia', 'Netanyahu', 'que', 'siempre', 'dice', 'que', 'su', 'familia', 'habitó', 'durante', 'muchas', 'generaciones', 'Israel', 'desde', 'antes', 'que', 'Palestina.', 'Y', 'el', 'chabón', 'es', 'polaco.', 'Que', 'basura', 'sionista', 'por', 'favor.', 'Mierda', 'sionista.', 'Como', 'el', 'comehermana.\n'], ['Israel.', 'Los', 'judíos', 'nazis', 'asesinos.', 'Comenzaron', 'el', 'último', 'ataque', 'contra', 'Gaza.', '😡😡😡😡😡😡😡😡\n'], ['Israel', 'mata', 'a', 'más', 'de', '100', 'palestinos', 'en', 'Gaza', 'en', 'nuevos', 'ataques', 'mientras', 'prepara', 'otra', 'ofensiva', 'terrestre', '', 'https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-una-ofensiva-terrestre.html', '', '#Israel', '#Gaza\n'], ['Israel', 'mata', 'a', 'más', 'de', '100', 'palestinos', 'en', 'Gaza', 'en', 'nuevos', 'ataques', 'mientras', 'prepara', 'otra', 'ofensiva', 'terrestre', '', 'https://elpais.com/internacional/2025-05-16/israel-mata-a-mas-de-50-palestinos-en-gaza-en-nuevos-ataques-mientras-prepara-u ...
# Número total de frases:  92
# Número total de palabras:  648
